# %%
import pandas as pd
import numpy as np

# %%
import json
from pprint import pprint

with open('suicide_squad.json') as f:
    data = json.load(f)

#pprint()
suicide_members = data['results']['characters']

# %%
head_size = 30

# %%
ss_pd = pd.DataFrame.from_dict(suicide_members)
ss_pd = ss_pd.set_index('id')
ss_pd['team']='Suicide Squad'
ss_pd= ss_pd.head(head_size)

# %%
with open('injustice_league.json') as f:
    data = json.load(f)

#pprint()
injustice_league_members = data['results']['characters']

# %%
il_pd = pd.DataFrame.from_dict(injustice_league_members)
il_pd = il_pd.set_index('id')
il_pd['team']='Injustice League'
il_pd= il_pd.head(head_size)

# %%
with open('x_men.json') as f:
    data = json.load(f)

#pprint()
x_men_members = data['results']['characters']

# %%
xm_pd = pd.DataFrame.from_dict(x_men_members)
xm_pd = xm_pd.set_index('id')
xm_pd['team']='X Men'
xm_pd = xm_pd.head(head_size)

# %%
with open('../data/ComicVine/characters.json') as f:
    data = json.load(f)
    
#pprint(data)

# %%
characters = pd.DataFrame.from_dict(data)
characters = characters.set_index('id')
characters=characters['origin']
characters.head()
# Out:
# id
# 1253    {'api_detail_url': 'https://comicvine.gamespot...
# 1254    {'api_detail_url': 'https://comicvine.gamespot...
# 1255    {'api_detail_url': 'https://comicvine.gamespot...
# 1256    {'api_detail_url': 'https://comicvine.gamespot...
# 1257    {'api_detail_url': 'https://comicvine.gamespot...
# Name: origin, dtype: object

# %%
SS = ss_pd.join(characters, how='inner')

# %%
IL = il_pd.join(characters, how='inner')

# %%
XM = xm_pd.join(characters, how='inner')

# %%
chars = pd.concat([SS, IL, XM])

# %%
chars.head()
# Out:
#                                            api_detail_url          name  \
# id
# 68435   https://comicvine.gamespot.com/api/character/4...     Adam Cray
# 126139  https://comicvine.gamespot.com/api/character/4...  Afterthought
# 23368   https://comicvine.gamespot.com/api/character/4...      Air Wave
# 146014  https://comicvine.gamespot.com/api/character/4...        Akando
# 152950  https://comicvine.gamespot.com/api/character/4...   Alchemaster
#
#                                           site_detail_url           team  \
# id
# 68435   https://comicvine.gamespot.com/adam-cray/4005-...  Suicide Squad
# 126139  https://comicvine.gamespot.com/afterthought/40...  Suicide Squad
# 23368   https://comicvine.gamespot.com/air-wave/4005-2...  Suicide Squad
# 146014  https://comicvine.gamespot.com/akando/4005-146...  Suicide Squad
# 152950  https://comicvine.gamespot.com/alchemaster/400...  Suicide Squad
#
#                                                    origin
# id
# 68435   {'api_detail_url': 'https://comicvine.gamespot...
# 126139  {'api_detail_url': 'https://comicvine.gamespot...
# 23368   {'api_detail_url': 'https://comicvine.gamespot...
# 146014  {'api_detail_url': 'https://comicvine.gamespot...
# 152950  {'api_detail_url': 'https://comicvine.gamespot...

# %%
id_ss=ss_pd.reset_index()['id']

# %%
from itertools import product
relationships = pd.DataFrame(list(product(id_ss, id_ss)), columns=['id1', 'id2'])

# %%
id_il=il_pd.reset_index()['id']

# %%
relationships = pd.concat([relationships, pd.DataFrame(list(product(id_il, id_il)), columns=['id1', 'id2'])])

# %%
id_xm=xm_pd.reset_index()['id']
relationships = pd.concat([relationships, pd.DataFrame(list(product(id_xm, id_xm)), columns=['id1', 'id2'])])

# %%
relationships.head()
# Out:
#      id1     id2
# 0  68435   68435
# 1  68435  126139
# 2  68435   23368
# 3  68435  146014
# 4  68435  152950

# %%
with open('origins.json') as f:
    data = json.load(f)

# %%
origins = pd.DataFrame.from_dict(data)
origins = origins.set_index('id')
origins.head()
# Out:
#                                        api_detail_url    name  \
# id
# 1   https://comicvine.gamespot.com/api/origin/4030-1/  Mutant
# 2   https://comicvine.gamespot.com/api/origin/4030-2/  Cyborg
# 3   https://comicvine.gamespot.com/api/origin/4030-3/   Alien
# 4   https://comicvine.gamespot.com/api/origin/4030-4/   Human
# 5   https://comicvine.gamespot.com/api/origin/4030-5/   Robot
#
#                                   site_detail_url
# id
# 1   https://comicvine.gamespot.com/mutant/4030-1/
# 2   https://comicvine.gamespot.com/cyborg/4030-2/
# 3    https://comicvine.gamespot.com/alien/4030-3/
# 4    https://comicvine.gamespot.com/human/4030-4/
# 5    https://comicvine.gamespot.com/robot/4030-5/

# %%
chars['origin'] = chars['origin'].apply(json.dumps)

# %%
chars
# Out:
#                                            api_detail_url               name  \
# id
# 68435   https://comicvine.gamespot.com/api/character/4...          Adam Cray
# 126139  https://comicvine.gamespot.com/api/character/4...       Afterthought
# 23368   https://comicvine.gamespot.com/api/character/4...           Air Wave
# 146014  https://comicvine.gamespot.com/api/character/4...             Akando
# 152950  https://comicvine.gamespot.com/api/character/4...        Alchemaster
# 4920    https://comicvine.gamespot.com/api/character/4...      Amanda Waller
# 2359    https://comicvine.gamespot.com/api/character/4...            Artemis
# 3583    https://comicvine.gamespot.com/api/character/4...       Arthur Light
# 4921    https://comicvine.gamespot.com/api/character/4...       Atom Smasher
# 132952  https://comicvine.gamespot.com/api/character/4...             Azucar
# 25850   https://comicvine.gamespot.com/api/character/4...               Babe
# 6129    https://comicvine.gamespot.com/api/character/4...               Bane
# 5368    https://comicvine.gamespot.com/api/character/4...     Barbara Gordon
# 1699    https://comicvine.gamespot.com/api/character/4...             Batman
# 127953  https://comicvine.gamespot.com/api/character/4...          Battleaxe
# 6029    https://comicvine.gamespot.com/api/character/4...           Behemoth
# 10189   https://comicvine.gamespot.com/api/character/4...            Big Sir
# 90001   https://comicvine.gamespot.com/api/character/4...              Bingo
# 8312    https://comicvine.gamespot.com/api/character/4...            Bizarro
# 4916    https://comicvine.gamespot.com/api/character/4...         Black Adam
# 8345    https://comicvine.gamespot.com/api/character/4...        Black Manta
# 5702    https://comicvine.gamespot.com/api/character/4...       Black Orchid
# 5812    https://comicvine.gamespot.com/api/character/4...       Black Spider
# 40815   https://comicvine.gamespot.com/api/character/4...         Blackguard
# 31109   https://comicvine.gamespot.com/api/character/4...         Blackstarr
# 55832   https://comicvine.gamespot.com/api/character/4...           Agamemno
# 88576   https://comicvine.gamespot.com/api/character/4...   Alexander Petrov
# 3737    https://comicvine.gamespot.com/api/character/4...              Amazo
# 3583    https://comicvine.gamespot.com/api/character/4...       Arthur Light
# 1699    https://comicvine.gamespot.com/api/character/4...             Batman
# ...                                                   ...                ...
# 10187   https://comicvine.gamespot.com/api/character/4...         Cluemaster
# 19006   https://comicvine.gamespot.com/api/character/4...      Count Vertigo
# 3588    https://comicvine.gamespot.com/api/character/4...        Deathstroke
# 9548    https://comicvine.gamespot.com/api/character/4...            Despero
# 19089   https://comicvine.gamespot.com/api/character/4...     Doctor Alchemy
# 15108   https://comicvine.gamespot.com/api/character/4...             Adam X
# 29255   https://comicvine.gamespot.com/api/character/4...            Alchemy
# 40909   https://comicvine.gamespot.com/api/character/4...      Aliyah Bishop
# 14896   https://comicvine.gamespot.com/api/character/4...    Alysande Stuart
# 10970   https://comicvine.gamespot.com/api/character/4...      Amanda Sefton
# 14868   https://comicvine.gamespot.com/api/character/4...       Amelia Voght
# 2112    https://comicvine.gamespot.com/api/character/4...              Angel
# 40593   https://comicvine.gamespot.com/api/character/4...    Angel Salvadore
# 40458   https://comicvine.gamespot.com/api/character/4...              Anole
# 15127   https://comicvine.gamespot.com/api/character/4...             Archer
# 13369   https://comicvine.gamespot.com/api/character/4...           Arclight
# 41840   https://comicvine.gamespot.com/api/character/4...              Ariel
# 4442    https://comicvine.gamespot.com/api/character/4...              Armor
# 10574   https://comicvine.gamespot.com/api/character/4...     Artie Maddicks
# 3189    https://comicvine.gamespot.com/api/character/4...             Aurora
# 3553    https://comicvine.gamespot.com/api/character/4...          Avalanche
# 125503  https://comicvine.gamespot.com/api/character/4...     Bailey Hoskins
# 9708    https://comicvine.gamespot.com/api/character/4...            Banshee
# 3188    https://comicvine.gamespot.com/api/character/4...               Beak
# 1462    https://comicvine.gamespot.com/api/character/4...              Beast
# 14552   https://comicvine.gamespot.com/api/character/4...  Beautiful Dreamer
# 15329   https://comicvine.gamespot.com/api/character/4...             Bedlam
# 30056   https://comicvine.gamespot.com/api/character/4...         Bird-Brain
# 1503    https://comicvine.gamespot.com/api/character/4...             Bishop
# 15111   https://comicvine.gamespot.com/api/character/4...          Black Box
#
#                                           site_detail_url              team  \
# id
# 68435   https://comicvine.gamespot.com/adam-cray/4005-...     Suicide Squad
# 126139  https://comicvine.gamespot.com/afterthought/40...     Suicide Squad
# 23368   https://comicvine.gamespot.com/air-wave/4005-2...     Suicide Squad
# 146014  https://comicvine.gamespot.com/akando/4005-146...     Suicide Squad
# 152950  https://comicvine.gamespot.com/alchemaster/400...     Suicide Squad
# 4920    https://comicvine.gamespot.com/amanda-waller/4...     Suicide Squad
# 2359    https://comicvine.gamespot.com/artemis/4005-2359/     Suicide Squad
# 3583    https://comicvine.gamespot.com/arthur-light/40...     Suicide Squad
# 4921    https://comicvine.gamespot.com/atom-smasher/40...     Suicide Squad
# 132952  https://comicvine.gamespot.com/azucar/4005-132...     Suicide Squad
# 25850     https://comicvine.gamespot.com/babe/4005-25850/     Suicide Squad
# 6129       https://comicvine.gamespot.com/bane/4005-6129/     Suicide Squad
# 5368    https://comicvine.gamespot.com/barbara-gordon/...     Suicide Squad
# 1699     https://comicvine.gamespot.com/batman/4005-1699/     Suicide Squad
# 127953  https://comicvine.gamespot.com/battleaxe/4005-...     Suicide Squad
# 6029    https://comicvine.gamespot.com/behemoth/4005-6...     Suicide Squad
# 10189   https://comicvine.gamespot.com/big-sir/4005-10...     Suicide Squad
# 90001    https://comicvine.gamespot.com/bingo/4005-90001/     Suicide Squad
# 8312    https://comicvine.gamespot.com/bizarro/4005-8312/     Suicide Squad
# 4916    https://comicvine.gamespot.com/black-adam/4005...     Suicide Squad
# 8345    https://comicvine.gamespot.com/black-manta/400...     Suicide Squad
# 5702    https://comicvine.gamespot.com/black-orchid/40...     Suicide Squad
# 5812    https://comicvine.gamespot.com/black-spider/40...     Suicide Squad
# 40815   https://comicvine.gamespot.com/blackguard/4005...     Suicide Squad
# 31109   https://comicvine.gamespot.com/blackstarr/4005...     Suicide Squad
# 55832   https://comicvine.gamespot.com/agamemno/4005-5...  Injustice League
# 88576   https://comicvine.gamespot.com/alexander-petro...  Injustice League
# 3737      https://comicvine.gamespot.com/amazo/4005-3737/  Injustice League
# 3583    https://comicvine.gamespot.com/arthur-light/40...  Injustice League
# 1699     https://comicvine.gamespot.com/batman/4005-1699/  Injustice League
# ...                                                   ...               ...
# 10187   https://comicvine.gamespot.com/cluemaster/4005...  Injustice League
# 19006   https://comicvine.gamespot.com/count-vertigo/4...  Injustice League
# 3588    https://comicvine.gamespot.com/deathstroke/400...  Injustice League
# 9548    https://comicvine.gamespot.com/despero/4005-9548/  Injustice League
# 19089   https://comicvine.gamespot.com/doctor-alchemy/...  Injustice League
# 15108   https://comicvine.gamespot.com/adam-x/4005-15108/             X Men
# 29255   https://comicvine.gamespot.com/alchemy/4005-29...             X Men
# 40909   https://comicvine.gamespot.com/aliyah-bishop/4...             X Men
# 14896   https://comicvine.gamespot.com/alysande-stuart...             X Men
# 10970   https://comicvine.gamespot.com/amanda-sefton/4...             X Men
# 14868   https://comicvine.gamespot.com/amelia-voght/40...             X Men
# 2112      https://comicvine.gamespot.com/angel/4005-2112/             X Men
# 40593   https://comicvine.gamespot.com/angel-salvadore...             X Men
# 40458    https://comicvine.gamespot.com/anole/4005-40458/             X Men
# 15127   https://comicvine.gamespot.com/archer/4005-15127/             X Men
# 13369   https://comicvine.gamespot.com/arclight/4005-1...             X Men
# 41840    https://comicvine.gamespot.com/ariel/4005-41840/             X Men
# 4442      https://comicvine.gamespot.com/armor/4005-4442/             X Men
# 10574   https://comicvine.gamespot.com/artie-maddicks/...             X Men
# 3189     https://comicvine.gamespot.com/aurora/4005-3189/             X Men
# 3553    https://comicvine.gamespot.com/avalanche/4005-...             X Men
# 125503  https://comicvine.gamespot.com/bailey-hoskins/...             X Men
# 9708    https://comicvine.gamespot.com/banshee/4005-9708/             X Men
# 3188       https://comicvine.gamespot.com/beak/4005-3188/             X Men
# 1462      https://comicvine.gamespot.com/beast/4005-1462/             X Men
# 14552   https://comicvine.gamespot.com/beautiful-dream...             X Men
# 15329   https://comicvine.gamespot.com/bedlam/4005-15329/             X Men
# 30056   https://comicvine.gamespot.com/bird-brain/4005...             X Men
# 1503     https://comicvine.gamespot.com/bishop/4005-1503/             X Men
# 15111   https://comicvine.gamespot.com/black-box/4005-...             X Men
#
#                                                    origin
# id
# 68435   {"api_detail_url": "https://comicvine.gamespot...
# 126139  {"api_detail_url": "https://comicvine.gamespot...
# 23368   {"api_detail_url": "https://comicvine.gamespot...
# 146014  {"api_detail_url": "https://comicvine.gamespot...
# 152950  {"api_detail_url": "https://comicvine.gamespot...
# 4920    {"api_detail_url": "https://comicvine.gamespot...
# 2359    {"api_detail_url": "https://comicvine.gamespot...
# 3583    {"api_detail_url": "https://comicvine.gamespot...
# 4921    {"api_detail_url": "https://comicvine.gamespot...
# 132952  {"api_detail_url": "https://comicvine.gamespot...
# 25850   {"api_detail_url": "https://comicvine.gamespot...
# 6129    {"api_detail_url": "https://comicvine.gamespot...
# 5368    {"api_detail_url": "https://comicvine.gamespot...
# 1699    {"api_detail_url": "https://comicvine.gamespot...
# 127953  {"api_detail_url": "https://comicvine.gamespot...
# 6029    {"api_detail_url": "https://comicvine.gamespot...
# 10189   {"api_detail_url": "https://comicvine.gamespot...
# 90001   {"api_detail_url": "https://comicvine.gamespot...
# 8312    {"api_detail_url": "https://comicvine.gamespot...
# 4916    {"api_detail_url": "https://comicvine.gamespot...
# 8345    {"api_detail_url": "https://comicvine.gamespot...
# 5702    {"api_detail_url": "https://comicvine.gamespot...
# 5812    {"api_detail_url": "https://comicvine.gamespot...
# 40815   {"api_detail_url": "https://comicvine.gamespot...
# 31109   {"api_detail_url": "https://comicvine.gamespot...
# 55832   {"api_detail_url": "https://comicvine.gamespot...
# 88576   {"api_detail_url": "https://comicvine.gamespot...
# 3737    {"api_detail_url": "https://comicvine.gamespot...
# 3583    {"api_detail_url": "https://comicvine.gamespot...
# 1699    {"api_detail_url": "https://comicvine.gamespot...
# ...                                                   ...
# 10187   {"api_detail_url": "https://comicvine.gamespot...
# 19006   {"api_detail_url": "https://comicvine.gamespot...
# 3588    {"api_detail_url": "https://comicvine.gamespot...
# 9548    {"api_detail_url": "https://comicvine.gamespot...
# 19089   {"api_detail_url": "https://comicvine.gamespot...
# 15108   {"api_detail_url": "https://comicvine.gamespot...
# 29255   {"api_detail_url": "https://comicvine.gamespot...
# 40909   {"api_detail_url": "https://comicvine.gamespot...
# 14896   {"api_detail_url": "https://comicvine.gamespot...
# 10970   {"api_detail_url": "https://comicvine.gamespot...
# 14868   {"api_detail_url": "https://comicvine.gamespot...
# 2112    {"api_detail_url": "https://comicvine.gamespot...
# 40593   {"api_detail_url": "https://comicvine.gamespot...
# 40458   {"api_detail_url": "https://comicvine.gamespot...
# 15127   {"api_detail_url": "https://comicvine.gamespot...
# 13369   {"api_detail_url": "https://comicvine.gamespot...
# 41840   {"api_detail_url": "https://comicvine.gamespot...
# 4442    {"api_detail_url": "https://comicvine.gamespot...
# 10574   {"api_detail_url": "https://comicvine.gamespot...
# 3189    {"api_detail_url": "https://comicvine.gamespot...
# 3553    {"api_detail_url": "https://comicvine.gamespot...
# 125503  {"api_detail_url": "https://comicvine.gamespot...
# 9708    {"api_detail_url": "https://comicvine.gamespot...
# 3188    {"api_detail_url": "https://comicvine.gamespot...
# 1462    {"api_detail_url": "https://comicvine.gamespot...
# 14552   {"api_detail_url": "https://comicvine.gamespot...
# 15329   {"api_detail_url": "https://comicvine.gamespot...
# 30056   {"api_detail_url": "https://comicvine.gamespot...
# 1503    {"api_detail_url": "https://comicvine.gamespot...
# 15111   {"api_detail_url": "https://comicvine.gamespot...
#
# [75 rows x 5 columns]

# %%
origin = chars['origin'].apply(json.loads)
origin = list(origin)

#origin = list(map(json.loads, origin))
origin = [d['name'] if d is not None else 'Undefined' for d in origin ]

# %%
chars['origin'] = origin
chars=chars[['name', 'team', 'origin']]
chars.head()
# Out:
#                   name              team  origin
# id
# 3588       Deathstroke  Injustice League   Human
# 3583      Arthur Light     Suicide Squad   Human
# 40458            Anole             X Men   Human
# 19006    Count Vertigo  Injustice League  Animal
# 14896  Alysande Stuart             X Men   Human

# %%
#relationships.sort_index(inplace=True)

from sklearn.utils import shuffle
chars = shuffle(chars)

# %%
chars.head()
# Out:
#                    name           team       origin
# id
# 15108            Adam X          X Men       Animal
# 127953        Battleaxe  Suicide Squad       Mutant
# 40593   Angel Salvadore          X Men  God/Eternal
# 125503   Bailey Hoskins          X Men        Human
# 9708            Banshee          X Men        Human

# %%
chars.to_csv('characters.csv')

# %%
relationships.head()
# Out:
#      id1     id2
# 0  68435   68435
# 1  68435  126139
# 2  68435   23368
# 3  68435  146014
# 4  68435  152950

# %%
relationships.head()
# Out:
#      id1     id2
# 0  68435   68435
# 1  68435  126139
# 2  68435   23368
# 3  68435  146014
# 4  68435  152950

# %%
relationships.to_csv('relationships.csv')
